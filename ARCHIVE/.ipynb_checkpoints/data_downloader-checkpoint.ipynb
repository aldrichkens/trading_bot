# %%
pip install --upgrade MetaTrader5
# Out:
# Requirement already satisfied: MetaTrader5 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (5.0.4738)
# Requirement already satisfied: numpy>=1.7 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (from MetaTrader5) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
# Initialize the connection
if not mt5.initialize():
    print("initialize() failed, error code =", mt5.last_error())
    quit()

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "AUDUSD"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 13)
utc_to = datetime(2025, 1, 15)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-13 00:00:00  0.61421  0.61421  0.61421  0.61421            1
# 1    2025-01-13 00:01:00  0.61423  0.61438  0.61405  0.61438            5
# 2    2025-01-13 00:02:00  0.61417  0.61441  0.61417  0.61438           10
# 3    2025-01-13 00:03:00  0.61453  0.61473  0.61438  0.61438            5
# 4    2025-01-13 00:04:00  0.61449  0.61467  0.61449  0.61467            2
# ...                  ...      ...      ...      ...      ...          ...
# 1014 2025-01-13 16:54:00  0.61531  0.61534  0.61524  0.61525           35
# 1015 2025-01-13 16:55:00  0.61524  0.61540  0.61524  0.61537           53
# 1016 2025-01-13 16:56:00  0.61536  0.61565  0.61536  0.61565           56
# 1017 2025-01-13 16:57:00  0.61564  0.61564  0.61554  0.61555           53
# 1018 2025-01-13 16:58:00  0.61555  0.61571  0.61553  0.61564           50
#
#       spread  real_volume
# 0        127            0
# 1         93            0
# 2         87            0
# 3         51            0
# 4         60            0
# ...      ...          ...
# 1014       8            0
# 1015       8            0
# 1016       8            0
# 1017       8            0
# 1018       8            0
#
# [1019 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                     time     open     high      low    close
# 979  2025-01-13 16:19:00  0.61474  0.61483  0.61470  0.61478
# 980  2025-01-13 16:20:00  0.61478  0.61487  0.61472  0.61481
# 981  2025-01-13 16:21:00  0.61482  0.61486  0.61468  0.61481
# 982  2025-01-13 16:22:00  0.61481  0.61485  0.61476  0.61478
