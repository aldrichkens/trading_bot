# %%
pip install --upgrade MetaTrader5
# Out:
# Requirement already satisfied: MetaTrader5 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (5.0.4738)
# Requirement already satisfied: numpy>=1.7 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (from MetaTrader5) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
# Initialize the connection
if not mt5.initialize():
    print("initialize() failed, error code =", mt5.last_error())
    quit()

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "EURJPY"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 14)
utc_to = datetime(2025, 1, 16)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-13 16:00:00  160.465  160.501  160.449  160.466           79
# 1    2025-01-13 16:01:00  160.469  160.528  160.462  160.489           91
# 2    2025-01-13 16:02:00  160.494  160.502  160.474  160.498           71
# 3    2025-01-13 16:03:00  160.496  160.500  160.466  160.473           73
# 4    2025-01-13 16:04:00  160.470  160.478  160.439  160.444           75
# ...                  ...      ...      ...      ...      ...          ...
# 1506 2025-01-14 17:06:00  162.106  162.181  162.106  162.172           83
# 1507 2025-01-14 17:07:00  162.172  162.181  162.153  162.161           76
# 1508 2025-01-14 17:08:00  162.159  162.210  162.134  162.181           94
# 1509 2025-01-14 17:09:00  162.175  162.211  162.166  162.203           75
# 1510 2025-01-14 17:10:00  162.203  162.203  162.203  162.203            1
#
#       spread  real_volume
# 0         20            0
# 1         20            0
# 2         20            0
# 3         20            0
# 4         20            0
# ...      ...          ...
# 1506      20            0
# 1507      20            0
# 1508      20            0
# 1509      20            0
# 1510      20            0
#
# [1511 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                     time     open     high      low    close
# 1471 2025-01-14 16:31:00  161.980  162.002  161.942  161.961
# 1472 2025-01-14 16:32:00  161.960  161.986  161.930  161.965
# 1473 2025-01-14 16:33:00  161.974  161.985  161.936  161.985
