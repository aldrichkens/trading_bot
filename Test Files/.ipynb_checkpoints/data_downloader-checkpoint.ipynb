# %%
# pip install --upgrade MetaTrader5

# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
if not mt5.initialize(login=89500879, server="MetaQuotes-Demo", password="6kF-FhYd"):
    print("Initialization failed")
    print(mt5.last_error())
    quit()

print("Connected to MT5 successfully")
# Out:
# Connected to MT5 successfully

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "GBPAUD"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 20)
utc_to = datetime(2025, 1, 22)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                    time     open     high      low    close  tick_volume  \
# 0   2025-01-20 00:01:00  1.96132  1.96151  1.96132  1.96151            2
# 1   2025-01-20 00:02:00  1.96283  1.96283  1.96151  1.96151            2
# 2   2025-01-20 00:03:00  1.96151  1.96151  1.96151  1.96151            1
# 3   2025-01-20 00:04:00  1.96188  1.96197  1.96174  1.96185            8
# 4   2025-01-20 00:05:00  1.96173  1.96174  1.96151  1.96152            6
# ..                  ...      ...      ...      ...      ...          ...
# 967 2025-01-20 16:08:00  1.96283  1.96319  1.96263  1.96297           86
# 968 2025-01-20 16:09:00  1.96296  1.96297  1.96254  1.96260           81
# 969 2025-01-20 16:10:00  1.96262  1.96276  1.96226  1.96259           73
# 970 2025-01-20 16:11:00  1.96277  1.96295  1.96242  1.96249           86
# 971 2025-01-20 16:12:00  1.96254  1.96291  1.96254  1.96267           33
#
#      spread  real_volume
# 0       500            0
# 1       200            0
# 2       560            0
# 3       478            0
# 4       499            0
# ..      ...          ...
# 967      33            0
# 968      37            0
# 969      33            0
# 970      33            0
# 971      34            0
#
# [972 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                    time     open     high      low    close
# 932 2025-01-20 15:33:00  1.96107  1.96153  1.95883  1.95940
# 933 2025-01-20 15:34:00  1.95946  1.96195  1.95901  1.96145
# 934 2025-01-20 15:35:00  1.96157  1.96230  1.96071  1.96114
# 935 2025-01-20 15:36:00  1.96131  1.96251  1.96066  1.96246
# 936 2025-01-20 15:37:00  1.96269  1.96311  1.96067  1.96108
