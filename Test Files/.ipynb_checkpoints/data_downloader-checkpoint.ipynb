# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
if not mt5.initialize(login=89500879, server="MetaQuotes-Demo", password="6kF-FhYd"):
    print("Initialization failed")
    print(mt5.last_error())
    quit()

print("Connected to MT5 successfully")
# Out:
# Connected to MT5 successfully

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "GBPUSD"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 29)
utc_to = datetime(2025, 1, 31)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-28 16:00:00  1.24234  1.24285  1.24234  1.24285           54
# 1    2025-01-28 16:01:00  1.24284  1.24304  1.24276  1.24301           52
# 2    2025-01-28 16:02:00  1.24297  1.24298  1.24276  1.24286           55
# 3    2025-01-28 16:03:00  1.24283  1.24314  1.24282  1.24314           46
# 4    2025-01-28 16:04:00  1.24314  1.24322  1.24290  1.24290           51
# ...                  ...      ...      ...      ...      ...          ...
# 1464 2025-01-29 16:25:00  1.24113  1.24116  1.24093  1.24094           40
# 1465 2025-01-29 16:26:00  1.24092  1.24104  1.24087  1.24091           47
# 1466 2025-01-29 16:27:00  1.24091  1.24124  1.24091  1.24113           55
# 1467 2025-01-29 16:28:00  1.24115  1.24121  1.24112  1.24116           44
# 1468 2025-01-29 16:29:00  1.24115  1.24115  1.24089  1.24103           28
#
#       spread  real_volume
# 0          5            0
# 1          5            0
# 2          5            0
# 3          5            0
# 4          5            0
# ...      ...          ...
# 1464       5            0
# 1465       5            0
# 1466       5            0
# 1467       5            0
# 1468       5            0
#
# [1469 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                     time     open     high      low    close
# 1429 2025-01-29 15:50:00  1.23969  1.23969  1.23947  1.23962
# 1430 2025-01-29 15:51:00  1.23961  1.23983  1.23950  1.23983
# 1431 2025-01-29 15:52:00  1.23981  1.23981  1.23963  1.23975
# 1432 2025-01-29 15:53:00  1.23976  1.24000  1.23974  1.23999
# 1433 2025-01-29 15:54:00  1.23996  1.23996  1.23973  1.23981
