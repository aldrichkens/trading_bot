# %%
pip install --upgrade MetaTrader5
# Out:
# Requirement already satisfied: MetaTrader5 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (5.0.4738)
# Requirement already satisfied: numpy>=1.7 in c:\users\aldri\appdata\local\anaconda3\lib\site-packages (from MetaTrader5) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
# Initialize the connection
if not mt5.initialize():
    print("initialize() failed, error code =", mt5.last_error())
    quit()

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "EURGBP"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 15)
utc_to = datetime(2025, 1, 17)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-14 16:00:00  0.84360  0.84379  0.84359  0.84376           60
# 1    2025-01-14 16:01:00  0.84377  0.84377  0.84354  0.84358           47
# 2    2025-01-14 16:02:00  0.84360  0.84370  0.84356  0.84362           46
# 3    2025-01-14 16:03:00  0.84363  0.84370  0.84357  0.84364           46
# 4    2025-01-14 16:04:00  0.84364  0.84380  0.84360  0.84380           39
# ...                  ...      ...      ...      ...      ...          ...
# 1510 2025-01-15 17:10:00  0.84145  0.84148  0.84136  0.84146           48
# 1511 2025-01-15 17:11:00  0.84148  0.84149  0.84129  0.84139           44
# 1512 2025-01-15 17:12:00  0.84139  0.84151  0.84133  0.84146           42
# 1513 2025-01-15 17:13:00  0.84145  0.84152  0.84138  0.84141           30
# 1514 2025-01-15 17:14:00  0.84141  0.84153  0.84140  0.84152           32
#
#       spread  real_volume
# 0         15            0
# 1         15            0
# 2         15            0
# 3         15            0
# 4         15            0
# ...      ...          ...
# 1510      15            0
# 1511      15            0
# 1512      15            0
# 1513      15            0
# 1514      15            0
#
# [1515 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                     time     open     high      low    close
# 1475 2025-01-15 16:35:00  0.84059  0.84060  0.84047  0.84050
# 1476 2025-01-15 16:36:00  0.84051  0.84070  0.84049  0.84067
# 1477 2025-01-15 16:37:00  0.84070  0.84082  0.84065  0.84074
# 1478 2025-01-15 16:38:00  0.84076  0.84078  0.84051  0.84054
