# %%
# pip install --upgrade MetaTrader5

# %%
import numpy
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime

# %%
if not mt5.initialize(login=89500879, server="MetaQuotes-Demo", password="6kF-FhYd"):
    print("Initialization failed")
    print(mt5.last_error())
    quit()

print("Connected to MT5 successfully")
# Out:
# Connected to MT5 successfully

# %%
#INPUTS
# SYMBOLS = AUDSD, EURUSD,EURJPY, XAUUSD, EURGPY, USDJPY
symbol = "USDCHF"
timeframe = mt5.TIMEFRAME_M1  # 1-minute timeframe
utc_from = datetime(2025, 1, 20)
utc_to = datetime(2025, 1, 22)

# %%
startdate=utc_from.strftime('%Y%m%d')
enddate=utc_to.strftime('%Y%m%d')

# %%
# Get the OHLC data
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)

# Check if the data is downloaded successfully
if rates is None:
    print("No data available, error code =", mt5.last_error())
else:
    # Convert the data to a pandas DataFrame
    rates_frame = pd.DataFrame(rates)
    # Convert the time in seconds to a datetime format
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')

    # Display the data
    print(rates_frame)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-20 00:01:00  0.91310  0.91310  0.91202  0.91202            2
# 1    2025-01-20 00:02:00  0.91210  0.91210  0.91206  0.91206            2
# 2    2025-01-20 00:03:00  0.91259  0.91259  0.91206  0.91230            4
# 3    2025-01-20 00:05:00  0.91250  0.91250  0.91250  0.91250            1
# 4    2025-01-20 00:06:00  0.91321  0.91325  0.91250  0.91265            6
# ...                  ...      ...      ...      ...      ...          ...
# 1054 2025-01-20 17:37:00  0.90854  0.90868  0.90820  0.90849           67
# 1055 2025-01-20 17:38:00  0.90848  0.90848  0.90810  0.90820           44
# 1056 2025-01-20 17:39:00  0.90826  0.90851  0.90823  0.90842           58
# 1057 2025-01-20 17:40:00  0.90842  0.90858  0.90840  0.90852           46
# 1058 2025-01-20 17:41:00  0.90861  0.90890  0.90859  0.90884           20
#
#       spread  real_volume
# 0         80            0
# 1        300            0
# 2        200            0
# 3        275            0
# 4         85            0
# ...      ...          ...
# 1054      13            0
# 1055      13            0
# 1056      13            0
# 1057      13            0
# 1058      12            0
#
# [1059 rows x 8 columns]

# %%
rates_frame.drop(["tick_volume", "spread", "real_volume"], inplace=True, axis=1)

# %%
rates_frame.tail(40)
# Out:
#                     time     open     high      low    close
# 1019 2025-01-20 17:02:00  0.90749  0.90774  0.90749  0.90757
# 1020 2025-01-20 17:03:00  0.90756  0.90762  0.90724  0.90738
# 1021 2025-01-20 17:04:00  0.90739  0.90739  0.90702  0.90721
# 1022 2025-01-20 17:05:00  0.90724  0.90733  0.90697  0.90704
# 1023 2025-01-20 17:06:00  0.90702  0.90744  0.90702  0.90743
